# %%
# pip install spotipy

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredential

# %%
cid = '27d4b0a80d34468791769ab01a80c3fa'
secret = 'ec2c9f838110449eb0c2668aee7c7d9e'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# 1000 of the greatest hits ever: Iris Fernanda 0hKruppKCtqPcSYgnCCVBg
sp.user_playlist_tracks("Iris Fernanda","0hKruppKCtqPcSYgnCCVBg")

# %%
#artist, album, trackname, loudness, key, mode, tempo, danceability, energy, instrumentalness liveness

# %%
def get_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

def get_songs(username, playlist_id):
    
    # Create empty dataframe
    playlist_features_list = ["artist","album","track_name","track_id","danceability","energy","key","loudness","mode","speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
    
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    
    # Loop through every track in the playlist, extract features and append the features to the playlist df
    
    playlist = get_playlist_tracks(username, playlist_id)
    
    for track in playlist:
        # Create empty dict
        playlist_features = {}
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]
        
        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [3])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
greatest_hits_ever_df = get_songs("Iris Fernanda","0hKruppKCtqPcSYgnCCVBg")
greatest_hits_ever_df
# Out:
#               artist                                              album  \
# 0    Various Artists  Singin' in the Rain (Original Motion Picture S...
# 1    Various Artists                       Rare Rock 'n Roll Essentials
# 2      Nat King Cole                                      Unforgettable
# 3       The Platters                      The Magic Touch: An Anthology
# 4         Bo Diddley                                         Bo Diddley
# ..               ...                                                ...
# 995        Tom Jones                                             Reload
# 996       Jamiroquai                                        Synkronized
# 997          Santana                      Supernatural (Legacy Edition)
# 998    Pet Shop Boys                                          Nightlife
# 999            Queen                                  Greatest Hits III
#
#                                    track_name                track_id  \
# 0                         Singin' In The Rain  5U3MkUWTpzj37A33GboDtv
# 1                                 Kansas City  2G5p8IwwzXSKBwE6r5zesN
# 2                               Unforgettable  648TTtYB0bH0P8Hfy0FmkL
# 3                    Only You (And You Alone)  0S5cs4lAkx99tGjoWS4Jtk
# 4                                   I'm A Man  760clbeDBWmBsBLbszWuNZ
# ..                                        ...                     ...
# 995                                   Sexbomb  6KHXp9QKpRuBQPLDOiZlsV
# 996                               Canned Heat  0RWqE2ZaulvnN1i40qIhDh
# 997                                    Smooth  3kenIsD2tMzxb8XtJlxi5J
# 998                         New York City Boy  60sxanUUz1xmUAGIfEdQVM
# 999  No One But You (Only The Good Die Young)  6r862ZdyJEHbiZsBOd186U
#
#     danceability energy key loudness mode speechiness instrumentalness  \
# 0          0.354  0.241   5  -13.811    1      0.0334         0.000274
# 1           0.72  0.539   0  -13.298    1      0.0453         0.000017
# 2          0.349  0.182   5  -13.507    1       0.031           0.0152
# 3          0.486  0.231   3   -12.06    1      0.0354                0
# 4          0.513  0.546   0  -15.672    1      0.0391                0
# ..           ...    ...  ..      ...  ...         ...              ...
# 995        0.801  0.876   8    -3.94    0      0.0446         0.000014
# 996          0.7  0.865   9   -5.827    0       0.133         0.000076
# 997        0.609  0.923   9   -3.908    1      0.0338         0.000005
# 998         0.72   0.99   2   -4.796    0      0.0473          0.00007
# 999        0.482  0.396   0   -8.348    0      0.0296                0
#
#     liveness valence    tempo duration_ms time_signature
# 0      0.165   0.408  135.646      294067              4
# 1      0.258   0.816  121.174      166107              4
# 2      0.143   0.178  136.094      191973              3
# 3      0.125   0.303   80.049      156667              4
# 4       0.17   0.834   85.527      164547              4
# ..       ...     ...      ...         ...            ...
# 995    0.104   0.932   122.98      211893              4
# 996   0.0718    0.78   128.04      331760              4
# 997    0.295   0.961  115.994      294987              4
# 998    0.223   0.878  130.972      315467              4
# 999   0.0927  0.0955  119.194      251333              3
#
# [1000 rows x 16 columns]

# %%
greatest_hits_ever_df.drop(['track_id'], axis=1)
# Out:
#               artist                                              album  \
# 0    Various Artists  Singin' in the Rain (Original Motion Picture S...
# 1    Various Artists                       Rare Rock 'n Roll Essentials
# 2      Nat King Cole                                      Unforgettable
# 3       The Platters                      The Magic Touch: An Anthology
# 4         Bo Diddley                                         Bo Diddley
# ..               ...                                                ...
# 995        Tom Jones                                             Reload
# 996       Jamiroquai                                        Synkronized
# 997          Santana                      Supernatural (Legacy Edition)
# 998    Pet Shop Boys                                          Nightlife
# 999            Queen                                  Greatest Hits III
#
#                                    track_name danceability energy key  \
# 0                         Singin' In The Rain        0.354  0.241   5
# 1                                 Kansas City         0.72  0.539   0
# 2                               Unforgettable        0.349  0.182   5
# 3                    Only You (And You Alone)        0.486  0.231   3
# 4                                   I'm A Man        0.513  0.546   0
# ..                                        ...          ...    ...  ..
# 995                                   Sexbomb        0.801  0.876   8
# 996                               Canned Heat          0.7  0.865   9
# 997                                    Smooth        0.609  0.923   9
# 998                         New York City Boy         0.72   0.99   2
# 999  No One But You (Only The Good Die Young)        0.482  0.396   0
#
#     loudness mode speechiness instrumentalness liveness valence    tempo  \
# 0    -13.811    1      0.0334         0.000274    0.165   0.408  135.646
# 1    -13.298    1      0.0453         0.000017    0.258   0.816  121.174
# 2    -13.507    1       0.031           0.0152    0.143   0.178  136.094
# 3     -12.06    1      0.0354                0    0.125   0.303   80.049
# 4    -15.672    1      0.0391                0     0.17   0.834   85.527
# ..       ...  ...         ...              ...      ...     ...      ...
# 995    -3.94    0      0.0446         0.000014    0.104   0.932   122.98
# 996   -5.827    0       0.133         0.000076   0.0718    0.78   128.04
# 997   -3.908    1      0.0338         0.000005    0.295   0.961  115.994
# 998   -4.796    0      0.0473          0.00007    0.223   0.878  130.972
# 999   -8.348    0      0.0296                0   0.0927  0.0955  119.194
#
#     duration_ms time_signature
# 0        294067              4
# 1        166107              4
# 2        191973              3
# 3        156667              4
# 4        164547              4
# ..          ...            ...
# 995      211893              4
# 996      331760              4
# 997      294987              4
# 998      315467              4
# 999      251333              3
#
# [1000 rows x 15 columns]
